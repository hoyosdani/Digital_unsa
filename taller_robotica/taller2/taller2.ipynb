# %% [markdown]
# # Taller 2

# %% [markdown]
# En este taller se profundizara en el lenguaje arduino, el cual es una variante del C++. Analizando nuevas sentencia y realizando algunos programas nuevos

# %% [markdown]
# ### Sintaxis

# %% [markdown]
# ####  Aritmetica
#
# Los operadores aritméticos incluyen suma, resta, multiplicación y división. Retorna la suma, diferencia, producto o cociente (respectivamente) de dos operandos.
# ```
# y = y+3;
# x = x-7;
# i = j*6;
# r = r/5;
# ```

# %% [markdown]
# #### 3.7 Variables
#
# Una variable es una forma de llamar y almacenar un valor numérico para usarse después por el programa. Como su nombre indica, las variables son números que pueden cambiarse continuamente al contrario que las constantes, cuyo valor nunca cambia. Una variable necesita ser declarada y, opcionalmente, asignada al valor que necesita para ser almacenada. Las variables tienen distintas formas de almacenar la informacion que se definen segun el dato que se decea utilizar. Los tipos de datos de arduino son:
#
# - byte: almacena un valor numérico de 8 bits sin puntos decimales. Tienen un rango de 0 a 255.
# 	```byte a = 180;```
# - int:  almacena un numero enteros es un valor de 16 bits con un rango de -32,768 a 32,767.
#     ``` int a = 1500; ```
# - long: Tipo de datos de tamaño extendido para enteros largos, sin puntos decimales, almacenados en un valor de 32 bits con un rango de -2,146,483,648 a 2,147,483,647.
# 	```long a = 90000;```
# - float: Un tipo de datos para números en punto otante, o números que tienen un punto decimal. Los números en punto flotante tienen mayor resolución que los enteros y se almacenan como valor de 32 bits con un rango de -3.4028235E+38 a 3.4028235E+38.
# 	```float a = 3.14;```
# - char: Un tipo de datos para presentar codigos ASCII simbolos y letras.
# 	```char a='c';  ```
# - arrays: Un array es una colección de valores que son accedidos con un índice numérico. Cualquier valor en el array debe llamarse escribiendo el nombre del array y el índice numérico del valor. Los arrays están indexados a cero, con el primer valor en el array comenzando con el índice número 0. Un array necesita ser declarado y opcionalmente asignarle valores antes de que puedan ser usados.
#     ```int a[] = {1, 2, 3...};```

# %% [markdown]
# #### Asignaciones compuestas
# Las asignaciones compuestas combinan una operación aritmética con una asignación de variable. Estas son muy frecuentemente encontradas en bucles for. Las asignaciones compuestas más comunes incluyen:
#         x++; //lo mismo que x = x+1
# 		x--; //lo mismo que x = x-1
# 		x += y; //lo mismo que x = x+y
# 		x -= y; //lo mismo que x = x-y
# 		x *= y; //lo mismo que x = x*y
# 		x /= y; //lo mismo que x = x/y
# #### Operadores de comparacion
# Las comparaciones de una variable o constante con otra se usan a menudo en declaraciones if para comprobar si un condición específica es cierta.
#
# 		```
#         x == y; //x es igual a y
# 		x != y; //x no es igual a y
# 		x < y; //x es menor que y
# 		x > y; //x es mayor que y
# 		x <= y; //x es menor o igual que y
# 		x >= y; //x es mayor o igual que y   ```
# #### Operadores logicos
# Los operadores lógicos son normalmente una forma de comparar dos expresiones y devuelve TRUE o FALSE dependiendo del operador. Hay tres operadores lógicos, AND, OR y NOT, que se usan a menudo en declaraciones if.
# - AND lógico: verdadero sólo si las dos expresiones son ciertas
# 		```if(x>0 && x<5)```
# - OR lógico: verdadero si al menos una expresión es cierta.
# 		```if(x>0 || y>0)```
# - NOT lógico:
# verdadero sólo si la expresión es falsa
# 		``` if(!(x>0)) ```

# %% [markdown]
# #### Salidas analogicas
#
#  analogWrite(pin, value): Escribe un valor pseudo analógico usando modulación por ancho de pulso a un pin de salida . En el esp8266 se puede utilizar cualquier pin. El valor puede ser especificado como una variable o constante con un valor de 0 a 1023.
#  Sintaxis:
#
# 		```analogWrite(pin, valor); //escribe 'valor' al 'pin' analogico
#         ```

# %% [markdown]
# ###  Control de Flujo
#
# - if: Las sentencias if comprueban si cierta condición ha sido alcanzada y ejecutan todas las sentencias dentro de las llaves si la declaración es cierta. Si es falsa el programa ignora la sentencia.
# ```
# 		if(a==0)
# 			{
# 			sentencias;
# 			}
# ```
# - if. . . else: permite tomar decisiones esto - o esto.
#   ```
# 	if(a == HIGH)
# 		{
# 		hacerA;
# 		}
# 	else
# 		{
# 		hacerB;
# 		} ```
# - for: La sentencia for se usa para repetir un bloque de declaraciones encerradas en llaves un número específico de veces. Un contador de incremento se usa a menudo para incrementar y terminar el bucle. Hay tres partes separadas por punto y coma (;), en la cabecera del bucle.
#    ```
# 		for(i=0; i<200; i++)
# 			{
# 			sentencias;
# 			}
#             ````
# - while: El bucle while se repetirá continuamente, e infinitamente, hasta que la expresión dentro del paréntesis se vuelva falsa. Algo debe cambiar la variable testeada, o el bucle while nunca saldrá. Esto podría estar en tu código, como por ejemplo una variable incrementada, o una condición externa, como un sensor de comprobación.
#  ```
# 		while(a<200)
# 			{
# 			a++;
# 			}
# ```

# %% [markdown]
# En la figura se muestra el circuito de prueba
# <img src="img/nodemcu_led.jpg" alt="Imagen"></img>

# %% [markdown]
# ### Ejercicio 1
# Realizar un programa que cambie la luz que emite el led de la placa de forma que pase de maximo a minimo en 10 segundos.

# %% [markdown]
# ## Programa a modificar

# %%
# %%writefile /home/dhoyos/jupyter_directorio/taller2/taller2.ino
#
# #include "config.h"
# void setup()
# {
#  configurarOTA();
# }
#
# void loop()
# {
# ArduinoOTA.handle();
# }

# %%
# !arduino-cli compile --fqbn  esp8266:esp8266:d1 --output-dir /home/dhoyos/jupyter_directorio/taller2/burn  /home/dhoyos/jupyter_directorio/taller2/taller2.ino
# !python espota.py -i 192.168.111.83 -p 8266 -f /home/dhoyos/jupyter_directorio/taller2/burn/taller2.ino.bin

# %% [markdown]
# ### Ejercicio 2
#
# Realizar un programa que cambie la luz que emite el led de la placa de forma que pase de minimo a maximo y de maximo a minmo en 10 segundos.

# %%
# %%writefile /home/dhoyos/jupyter_directorio/taller2/taller2.ino
#
# #include "config.h"
# void setup()
# {
#  configurarOTA();
#
# }
#
#
# void loop()
# {
# ArduinoOTA.handle();
#
# }
# Out:
# Overwriting /home/dhoyos/jupyter_directorio/taller2/taller2.ino

# %%
# !arduino-cli compile --fqbn  esp8266:esp8266:d1 --output-dir /home/dhoyos/jupyter_directorio/taller2/burn  /home/dhoyos/jupyter_directorio/taller2/taller2.ino
# !python espota.py -i 192.168.111.83 -p 8266 -f /home/dhoyos/jupyter_directorio/taller2/burn/taller2.ino.bin
# Out:
# . Variables and constants in RAM (global, static), used 29032 / 80192 bytes (36%)
# ║   SEGMENT  BYTES    DESCRIPTION
# ╠══ DATA     1512     initialized variables
# ╠══ RODATA   1384     constants
# ╚══ BSS      26136    zeroed variables
# . Instruction RAM (IRAM_ATTR, ICACHE_RAM_ATTR), used 61316 / 65536 bytes (93%)
# ║   SEGMENT  BYTES    DESCRIPTION
# ╠══ ICACHE   32768    reserved space for flash instruction cache
# ╚══ IRAM     28548    code in IRAM
# . Code in flash (default, ICACHE_FLASH_ATTR), used 285148 / 1048576 bytes (27%)
# ║   SEGMENT  BYTES    DESCRIPTION
# ╚══ IROM     285148   code in flash
# Uploading............................................................................................................................................................................................................................

# %%
# !python espota.py -i 192.168.111.83 -p 8266 -f /home/dhoyos/jupyter_directorio/taller2/burn/taller2.ino.bin
# Out:
# Uploading............................................................................................................................................................................................................................

# %% [markdown]
# ### Ejercicio 3
#
# Realizar un programa que muestre los siguientes colores durante 1 segundo. Rojo, verde, azul, amarillo, violeta,
